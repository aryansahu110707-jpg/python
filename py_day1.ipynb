# %%
print('Hello world')
# Out:
# Hello world

# %%
print(False)
# Out:
# False

# %%
#int float string bool

# %%
#Phyton is a case sensitive language

# %%
#boolian (first letter capital)

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %%
print('hello',2,4.5,True)
# Out:
# hello 2 4.5 True

# %%
print('hello',2,4.5,True,sep='/')
# Out:
# hello/2/4.5/True

# %% [markdown]
# # 2. data type

# %%
#integer
print(8)
# Out:
# 8

# %%
#decimal/float
print(7.8)
# Out:
# 7.8

# %%
#boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#text/string
print('hello world')
# Out:
# hello world

# %%
#complex
print(5+6j)
# Out:
# (5+6j)

# %%
#list-> c-> array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary
print({'name': 'Aryan'})
# Out:
# {'name': 'Aryan'}

# %%
#type
type([1,2,3])
# Out:
# list

# %%
type(1)
# Out:
# int

# %% [markdown]
# # 3. Variables

# %%
name = 'Aryan'
print(name)
# Out:
# Aryan

# %%
a=5
b=6
print(a+b)
# Out:
# 11

# %%
a=5
print(a)
a=6
print(a)
# Out:
# 5
# 6

# %%
a,b,c=1,2,3 
print(a,b,c,sep='/')
# Out:
# 1/2/3

# %%
a=b=c=5
print(a+b+c)
# Out:
# 15

# %% [markdown]
# # 4. Keywords & Identifiers

# %%
#IDENTIFIERS
#you can't start with digit
#eg: 
1name= aryan
print(1name)
# Out:
#   Cell In[116], line 4
#     1name= aryan
#     ^
# SyntaxError: invalid decimal literal

# %%
name1='Aryan'
print(name1)
# Out:
# Aryan

# %%
#we can use uppercase or lowercase and special character only -> _ 
_='Aryan'
print(_)
# Out:
# Aryan

# %% [markdown]
# # identifiers can't be keywords

# %% [markdown]
# # 5. User Input

# %%
input('enter your name')
# Out:
# enter your name aryan
# 'aryan'

# %%
# take input from users and store them in variable
fnum = input('enter first number')
snum = input('enter second number')
print(type(fnum),type(snum))
# add the 2 variables
result= fnum+snum
# print the result 
print(result)
# Out:
# enter first number 56
# enter second number 4
# <class 'str'> <class 'str'>
# 564

# %%
# take input from users and store them in variable
fnum = input('enter first number')
snum = input('enter second number')
print(type(fnum),type(snum))
# add the 2 variables
result= int(fnum)+int(snum)
# print the result 
print(result)
print(type(fnum))
# Out:
# enter first number 56
# enter second number 4
# <class 'str'> <class 'str'>
# 60
# <class 'str'>

# %%
#OR
# take input from users and store them in variable
fnum = int(input('enter first number'))
snum = int(input('enter second number'))
print(type(fnum),type(snum))
# add the 2 variables
result= fnum+snum
# print the result 
print(result)
print(type(fnum))
# Out:
# enter first number 56
# enter second number 4
# <class 'int'> <class 'int'>
# 60
# <class 'int'>

# %% [markdown]
# # 7. Literals

# %%
a= 0b1010 #binary literals
b= 100 #decimal literals
c= 0o310 #octal literals
d= 0x12c #hexadecimal literals
print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 100
# 200
# 300

# %%
#float literals
a=10.5
b=1.5e2 #1.5*10^2
c=1.5e-3
print(a)
print(b)
print(c)
# Out:
# 10.5
# 150.0
# 0.0015

# %%
#complex literals
x=5+4j
print(x,x.real,x.imag)
# Out:
# (5+4j) 5.0 4.0

# %%
a=True + 4 #becase true=1 and false=0 
b= False + 4
print(a)
print(b)
# Out:
# 5
# 4

# %%
a=None
print(a)
# Out:
# None
